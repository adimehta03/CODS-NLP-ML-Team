# %%
import tweepy
import json
import pandas as pd

# import twitter_credentials
consumer_key = "cFf7im7BH68xO9qh3zEsv3nFz"
consumer_secret = "2QyodEVK63XYE5D9RFPAo0I53rhBOsNocQGpGB8rapmEqxDnJi"
access_key = "1265319352795975680-EJBIU55ZHZnjn8svR420cqVuU9evRL"
access_secret = "i8h2utF6b2l2Uh7Vpg6c2mnPOO1CuthGdbyWtHSWdIURP"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret) 
auth.set_access_token(access_key, access_secret) 
api = tweepy.API(auth) 

screenname = "CMofKarnataka"
tweet, tweets_dates, img_url, img = [], [], [], []

tweets = api.user_timeline(screen_name=screenname,count=200,tweet_mode="extended")  

for status in tweets:
    if "Total Confirmed Cases: " in status.full_text:
        tweet.append(status.full_text)
        tweets_dates.append(status.created_at)
        for media in status.extended_entities['media']:
            img_url.append(media['media_url'])
        img.append(img_url)
        img_url=[]    
for i in img:
    img_url.append(i[1])
df = pd.DataFrame({"Image URL":img_url})
df.to_csv(screenname+'.csv')
df
# Out:
#                                          Image URL
# 0   http://pbs.twimg.com/media/EazVmxCUYAYP8QM.jpg
# 1   http://pbs.twimg.com/media/EauAVhbWsAADcnD.jpg
# 2   http://pbs.twimg.com/media/Eao_bytXsAgoc_L.jpg
# 3   http://pbs.twimg.com/media/EajvGXNXkAcftIc.jpg
# 4   http://pbs.twimg.com/media/EaeejqdUcAMSKzu.jpg
# 5   http://pbs.twimg.com/media/EaZUT4vVAAEBje2.jpg
# 6   http://pbs.twimg.com/media/EaUQM53WsAEcw8_.jpg
# 7   http://pbs.twimg.com/media/EaO1p-4XYAIDaG7.jpg
# 8   http://pbs.twimg.com/media/EaJv1sfVAAIGltx.jpg
# 9   http://pbs.twimg.com/media/EaEz3P0WkAA4E4j.jpg
# 10  http://pbs.twimg.com/media/EZ_rQ0_XsAADZCP.jpg
# 11  http://pbs.twimg.com/media/EZ6UgB_XQAElTEZ.jpg
# 12  http://pbs.twimg.com/media/EZ1UWTnUwAA3le8.jpg
# 13  http://pbs.twimg.com/media/EZv_TteWoAImYp-.jpg
# 14  http://pbs.twimg.com/media/EZrBen_XgAEuuqM.jpg
# 15  http://pbs.twimg.com/media/EZmH3H4WkAY1UO4.jpg
# 16  http://pbs.twimg.com/media/EZhN3kYWsAEjrp3.jpg

# %%
import tweepy
import json
import pandas as pd

# import twitter_credentials
consumer_key = "cFf7im7BH68xO9qh3zEsv3nFz"
consumer_secret = "2QyodEVK63XYE5D9RFPAo0I53rhBOsNocQGpGB8rapmEqxDnJi"
access_key = "1265319352795975680-EJBIU55ZHZnjn8svR420cqVuU9evRL"
access_secret = "i8h2utF6b2l2Uh7Vpg6c2mnPOO1CuthGdbyWtHSWdIURP"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret) 
auth.set_access_token(access_key, access_secret) 
api = tweepy.API(auth) 

screenname = "CMofKarnataka"
tweet, tweets_dates, img_url, img = [], [], [], []

tweets = api.user_timeline(screen_name=screenname,count=200,tweet_mode="extended")  
tweet = []
tweets_dates = []
img_url = []
img = []

for status in tweets:
    if "Total Confirmed Cases: " in status.full_text:
        tweet.append(status.full_text)
        tweets_dates.append(status.created_at)
        for media in status.extended_entities['media']:
            img_url.append(media['media_url'])
        img.append(img_url)
        img_url=[]    
for i in img:
    img_url.append(i[1])
df = pd.DataFrame({"Tweets":tweet,"Date Created":tweets_dates,"Image URL":img_url})
df.to_csv(screenname+'.csv')
df["Date Created"]=df['Date Created'].dt.date
df
# Out:
#                                                Tweets Date Created  \
# 0   Covid19 Bulletin: 19th June 2020\n\nTotal Conf...   2020-06-19
# 1   Covid19 Bulletin: 18th June 2020\n\nTotal Conf...   2020-06-18
# 2   Covid19 Bulletin: 17th June 2020\n\nTotal Conf...   2020-06-17
# 3   Covid19 Bulletin: 16th June 2020\n\nTotal Conf...   2020-06-16
# 4   Covid19 Bulletin: 15th June 2020\n\nTotal Conf...   2020-06-15
# 5   Covid19 Bulletin: 14th June 2020\n\nTotal Conf...   2020-06-14
# 6   Covid19 Bulletin: 13th June 2020\n\nTotal Conf...   2020-06-13
# 7   Covid19 Bulletin: 12th June 2020\n\nTotal Conf...   2020-06-12
# 8   Covid19 Bulletin: 11th June 2020\n\nTotal Conf...   2020-06-11
# 9   Covid19 Bulletin: 10th June 2020\n\nTotal Conf...   2020-06-10
# 10  Covid19 Bulletin: 9th June 2020\n\nTotal Confi...   2020-06-09
# 11  Covid19 Bulletin: 8th June 2020\n\nTotal Confi...   2020-06-08
# 12  Covid19 Bulletin: 7th June 2020\n\nTotal Confi...   2020-06-07
# 13  Covid19 Bulletin: 6th June 2020\n\nTotal Confi...   2020-06-06
# 14  Covid19 Bulletin: 5th June 2020\n\nTotal Confi...   2020-06-05
# 15  Covid19 Bulletin: 4th June 2020\n\nTotal Confi...   2020-06-04
# 16  Covid19 Bulletin: 3rd June  2020\n\nTotal Conf...   2020-06-03
#
#                                          Image URL
# 0   http://pbs.twimg.com/media/Ea4rp8yX0AYWGpa.jpg
# 1   http://pbs.twimg.com/media/EazVmxCUYAYP8QM.jpg
# 2   http://pbs.twimg.com/media/EauAVhbWsAADcnD.jpg
# 3   http://pbs.twimg.com/media/Eao_bytXsAgoc_L.jpg
# 4   http://pbs.twimg.com/media/EajvGXNXkAcftIc.jpg
# 5   http://pbs.twimg.com/media/EaeejqdUcAMSKzu.jpg
# 6   http://pbs.twimg.com/media/EaZUT4vVAAEBje2.jpg
# 7   http://pbs.twimg.com/media/EaUQM53WsAEcw8_.jpg
# 8   http://pbs.twimg.com/media/EaO1p-4XYAIDaG7.jpg
# 9   http://pbs.twimg.com/media/EaJv1sfVAAIGltx.jpg
# 10  http://pbs.twimg.com/media/EaEz3P0WkAA4E4j.jpg
# 11  http://pbs.twimg.com/media/EZ_rQ0_XsAADZCP.jpg
# 12  http://pbs.twimg.com/media/EZ6UgB_XQAElTEZ.jpg
# 13  http://pbs.twimg.com/media/EZ1UWTnUwAA3le8.jpg
# 14  http://pbs.twimg.com/media/EZv_TteWoAImYp-.jpg
# 15  http://pbs.twimg.com/media/EZrBen_XgAEuuqM.jpg
# 16  http://pbs.twimg.com/media/EZmH3H4WkAY1UO4.jpg

# %%
case  = []
title = []
cases = []
for i in tweet:
    index = i.split("\n").index('')
    val = i.split("\n")
    rindex = (len(val) -1) - list(reversed(val)).index('')
    split_tweets = (val[index+1:rindex])

    count = 0
    for i in split_tweets:
            count += 1
            title.append(i.split(': ')[0])
            case.append(int(i.split(": ")[1]))
#             print(i.split(": "))
            if count == 4:
                break
    cases.append(case)
    case = []
title = title[:4]
print(cases,title)
# Out:
# [[8281, 124, 5210, 337], [7944, 114, 4983, 210], [7734, 102, 4804, 204], [7530, 94, 4456, 317], [7213, 88, 4135, 213], [7000, 86, 3955, 176], [6824, 81, 3648, 308], [6516, 79, 3440, 271], [6245, 72, 2976, 204], [6041, 69, 2862, 120], [5921, 66, 2605, 161], [5760, 64, 2519, 308], [5452, 61, 2132, 239], [5213, 59, 1968, 378], [4835, 57, 1688, 515], [4320, 57, 1610, 257], [4063, 53, 1514, 267]] ['Total Confirmed Cases', 'Deceased', 'Recovered', 'New Cases']

# %%
df2 = pd.DataFrame(columns = title, data = cases)

# %%
df2["Date Created"] = df["Date Created"]

# %%
df2
# Out:
#     Total Confirmed Cases  Deceased  Recovered  New Cases Date Created
# 0                    8281       124       5210        337   2020-06-19
# 1                    7944       114       4983        210   2020-06-18
# 2                    7734       102       4804        204   2020-06-17
# 3                    7530        94       4456        317   2020-06-16
# 4                    7213        88       4135        213   2020-06-15
# 5                    7000        86       3955        176   2020-06-14
# 6                    6824        81       3648        308   2020-06-13
# 7                    6516        79       3440        271   2020-06-12
# 8                    6245        72       2976        204   2020-06-11
# 9                    6041        69       2862        120   2020-06-10
# 10                   5921        66       2605        161   2020-06-09
# 11                   5760        64       2519        308   2020-06-08
# 12                   5452        61       2132        239   2020-06-07
# 13                   5213        59       1968        378   2020-06-06
# 14                   4835        57       1688        515   2020-06-05
# 15                   4320        57       1610        257   2020-06-04
# 16                   4063        53       1514        267   2020-06-03

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
# %matplotlib inline

# %%
plt.figure(figsize=(12,6))
ax = sns.barplot(x = df["Date Created"][::-1],y=df2['Total Confirmed Cases'],palette="Blues")
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()
ax.figure.savefig("./images/Karnataka-TCC.png")

# %%
plt.figure(figsize=(12,6))
ax = sns.barplot(x = df["Date Created"][::-1],y=df2['Deceased'],palette="Blues")
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()
ax.figure.savefig("./images/Karnataka-DC.png")

# %%
plt.figure(figsize=(12,6))
ax = sns.barplot(x = df["Date Created"][::-1],y=df2['Recovered'],palette="Blues")
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()
ax.figure.savefig("./images/Karnataka-RC.png")

# %%
plt.figure(figsize=(12,6))
ax = sns.barplot(x = df["Date Created"][::-1],y=df2['New Cases'],palette="Blues")
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()
ax.figure.savefig("./images/Karnataka-NC.png")
