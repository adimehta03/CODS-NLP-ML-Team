# %%
import tweepy
import json
import pandas as pd

# import twitter_credentials
consumer_key = "cFf7im7BH68xO9qh3zEsv3nFz"
consumer_secret = "2QyodEVK63XYE5D9RFPAo0I53rhBOsNocQGpGB8rapmEqxDnJi"
access_key = "1265319352795975680-EJBIU55ZHZnjn8svR420cqVuU9evRL"
access_secret = "i8h2utF6b2l2Uh7Vpg6c2mnPOO1CuthGdbyWtHSWdIURP"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret) 
auth.set_access_token(access_key, access_secret) 
api = tweepy.API(auth) 

screenname = "CMofKarnataka"
tweet, tweets_dates, img_url, img = [], [], [], []

tweets = api.user_timeline(screen_name=screenname,count=200,tweet_mode="extended")  

for status in tweets:
    if "Total Confirmed Cases: " in status.full_text:
        tweet.append(status.full_text)
        tweets_dates.append(status.created_at)
        for media in status.extended_entities['media']:
            img_url.append(media['media_url'])
        img.append(img_url)
        img_url=[]    
for i in img:
    img_url.append(i[1])
df = pd.DataFrame({"Image URL":img_url})
df.to_csv(screenname+'.csv')
df
# Out:
#                                          Image URL
# 0   http://pbs.twimg.com/media/EcVQi4HXkAQs9T8.jpg
# 1   http://pbs.twimg.com/media/EcQMzLBXsAUexAV.jpg
# 2   http://pbs.twimg.com/media/EcK9a3TWAAEsGwS.jpg
# 3   http://pbs.twimg.com/media/EcFwqS5WoAEr7wG.jpg
# 4   http://pbs.twimg.com/media/EcAtTMBXsAMFQCQ.jpg
# 5   http://pbs.twimg.com/media/Eb7S6BZWsAgPS4H.jpg
# 6   http://pbs.twimg.com/media/Eb2R8ZEWsAYujno.jpg
# 7   http://pbs.twimg.com/media/EbxHln2U4AMTiWG.jpg
# 8   http://pbs.twimg.com/media/EbsSxa_XYAcaT3A.jpg
# 9   http://pbs.twimg.com/media/Ebm3xfSXkAA_MDY.jpg
# 10  http://pbs.twimg.com/media/Ebh9oClU8AEOgIC.jpg
# 11  http://pbs.twimg.com/media/EbcnLmdXkAEfndu.jpg
# 12  http://pbs.twimg.com/media/EbXhIqhXQAET3A2.jpg
# 13  http://pbs.twimg.com/media/EbSLZRGX0AAulEK.jpg
# 14  http://pbs.twimg.com/media/EbNDEe5WAAEOzzW.jpg
# 15  http://pbs.twimg.com/media/EbHrwP7UMAIJKiC.jpg
# 16  http://pbs.twimg.com/media/EbCp5weXQAYubMO.jpg
# 17  http://pbs.twimg.com/media/Ea9fxneWkAUxEp0.jpg
# 18  http://pbs.twimg.com/media/Ea4rp8yX0AYWGpa.jpg
# 19  http://pbs.twimg.com/media/EazVmxCUYAYP8QM.jpg

# %%
import tweepy
import json
import pandas as pd

# import twitter_credentials
consumer_key = "cFf7im7BH68xO9qh3zEsv3nFz"
consumer_secret = "2QyodEVK63XYE5D9RFPAo0I53rhBOsNocQGpGB8rapmEqxDnJi"
access_key = "1265319352795975680-EJBIU55ZHZnjn8svR420cqVuU9evRL"
access_secret = "i8h2utF6b2l2Uh7Vpg6c2mnPOO1CuthGdbyWtHSWdIURP"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret) 
auth.set_access_token(access_key, access_secret) 
api = tweepy.API(auth) 

screenname = "CMofKarnataka"
tweet, tweets_dates, img_url, img = [], [], [], []

tweets = api.user_timeline(screen_name=screenname,count=200,tweet_mode="extended")  
tweet = []
tweets_dates = []
img_url = []
img = []

for status in tweets:
    if "Total Confirmed Cases: " in status.full_text:
        tweet.append(status.full_text)
        tweets_dates.append(status.created_at)
        for media in status.extended_entities['media']:
            img_url.append(media['media_url'])
        img.append(img_url)
        img_url=[]    
for i in img:
    img_url.append(i[1])
df = pd.DataFrame({"Tweets":tweet,"Date Created":tweets_dates,"Image URL":img_url})
df.to_csv(screenname+'.csv')
df["Date Created"]=df['Date Created'].dt.date
df
# Out:
#                                                Tweets Date Created  \
# 0   Covid19 Bulletin: 7th July 2020\n\nTotal Confi...   2020-07-07
# 1   Covid19 Bulletin: 6th July 2020\n\nTotal Confi...   2020-07-06
# 2   Covid19 Bulletin: 5th July 2020\n\nTotal Confi...   2020-07-05
# 3   Covid19 Bulletin: 4th July 2020\n\nTotal Confi...   2020-07-04
# 4   Covid19 Bulletin: 3rd July 2020\n\nTotal Confi...   2020-07-03
# 5   Covid19 Bulletin: 2nd July 2020\n\nTotal Confi...   2020-07-02
# 6   Covid19 Bulletin: 1st July 2020\n\nTotal Confi...   2020-07-01
# 7   Covid19 Bulletin: 30th June 2020\n\nTotal Conf...   2020-06-30
# 8   Covid19 Bulletin: 29th June 2020\n\nTotal Conf...   2020-06-29
# 9   Covid19 Bulletin: 28th June 2020\n\nTotal Conf...   2020-06-28
# 10  Covid19 Bulletin: 27th June 2020\n\nTotal Conf...   2020-06-27
# 11  Covid19 Bulletin: 26th June 2020\n\nTotal Conf...   2020-06-26
# 12  Covid19 Bulletin: 25th June 2020\n\nTotal Conf...   2020-06-25
# 13  Covid19 Bulletin: 24th June 2020\n\nTotal Conf...   2020-06-24
# 14  Covid19 Bulletin: 23rd June 2020\n\nTotal Conf...   2020-06-23
# 15  Covid19 Bulletin: 22rd June 2020\n\nTotal Conf...   2020-06-22
# 16  Covid19 Bulletin: 21st June 2020\n\nTotal Conf...   2020-06-21
# 17  Covid19 Bulletin: 20th June 2020\n\nTotal Conf...   2020-06-20
# 18  Covid19 Bulletin: 19th June 2020\n\nTotal Conf...   2020-06-19
# 19  Covid19 Bulletin: 18th June 2020\n\nTotal Conf...   2020-06-18
#
#                                          Image URL
# 0   http://pbs.twimg.com/media/EcVQi4HXkAQs9T8.jpg
# 1   http://pbs.twimg.com/media/EcQMzLBXsAUexAV.jpg
# 2   http://pbs.twimg.com/media/EcK9a3TWAAEsGwS.jpg
# 3   http://pbs.twimg.com/media/EcFwqS5WoAEr7wG.jpg
# 4   http://pbs.twimg.com/media/EcAtTMBXsAMFQCQ.jpg
# 5   http://pbs.twimg.com/media/Eb7S6BZWsAgPS4H.jpg
# 6   http://pbs.twimg.com/media/Eb2R8ZEWsAYujno.jpg
# 7   http://pbs.twimg.com/media/EbxHln2U4AMTiWG.jpg
# 8   http://pbs.twimg.com/media/EbsSxa_XYAcaT3A.jpg
# 9   http://pbs.twimg.com/media/Ebm3xfSXkAA_MDY.jpg
# 10  http://pbs.twimg.com/media/Ebh9oClU8AEOgIC.jpg
# 11  http://pbs.twimg.com/media/EbcnLmdXkAEfndu.jpg
# 12  http://pbs.twimg.com/media/EbXhIqhXQAET3A2.jpg
# 13  http://pbs.twimg.com/media/EbSLZRGX0AAulEK.jpg
# 14  http://pbs.twimg.com/media/EbNDEe5WAAEOzzW.jpg
# 15  http://pbs.twimg.com/media/EbHrwP7UMAIJKiC.jpg
# 16  http://pbs.twimg.com/media/EbCp5weXQAYubMO.jpg
# 17  http://pbs.twimg.com/media/Ea9fxneWkAUxEp0.jpg
# 18  http://pbs.twimg.com/media/Ea4rp8yX0AYWGpa.jpg
# 19  http://pbs.twimg.com/media/EazVmxCUYAYP8QM.jpg

# %%
case  = []
title = []
cases = []
for i in tweet:
    index = i.split("\n").index('')
    val = i.split("\n")
    rindex = (len(val) -1) - list(reversed(val)).index('')
    split_tweets = (val[index+1:rindex])

    count = 0
    for i in split_tweets:
            count += 1
            title.append(i.split(': ')[0])
            case.append((i.split(": ")[1]))
#             print(i.split(": "))
            if count == 4:
                break
    cases.append(case)
    case = []
title = title[:4]
print(cases,title)
# Out:
# [['26,815', '416', '11,098', '1498'], ['25317', '401', '10,527', '1843'], ['23474', '372', '9847', '1925'], ['21549', '335', '9244', '1839'], ['19710', '293', '8805', '1694'], ['18016', '272', '8334', '1502'], ['16514', '253', '8063', '1272'], ['15242', '246', '7918', '947'], ['14,295', '226', '7683', '1105'], ['13190', '207', '7507', '1267'], ['11923', '191', '7287', '918'], ['11005', '180', '6916', '445'], ['10560', '170', '6670', '442'], ['10118', '164', '6151', '397'], ['9721', '150', '6004', '322'], ['9399', '142', '5730', '249'], ['9150', '137', '5618', '453'], ['8697', '132', '5391', '416'], ['8281', '124', '5210', '337'], ['7944', '114', '4983', '210']] ['Total Confirmed Cases', 'Deceased', 'Recovered', 'New Cases']

# %%
df2 = pd.DataFrame(columns = title, data = cases)

# %%
df2["Date Created"] = df["Date Created"]

# %%
df2
# Out:
#    Total Confirmed Cases Deceased Recovered New Cases Date Created
# 0                 26,815      416    11,098      1498   2020-07-07
# 1                  25317      401    10,527      1843   2020-07-06
# 2                  23474      372      9847      1925   2020-07-05
# 3                  21549      335      9244      1839   2020-07-04
# 4                  19710      293      8805      1694   2020-07-03
# 5                  18016      272      8334      1502   2020-07-02
# 6                  16514      253      8063      1272   2020-07-01
# 7                  15242      246      7918       947   2020-06-30
# 8                 14,295      226      7683      1105   2020-06-29
# 9                  13190      207      7507      1267   2020-06-28
# 10                 11923      191      7287       918   2020-06-27
# 11                 11005      180      6916       445   2020-06-26
# 12                 10560      170      6670       442   2020-06-25
# 13                 10118      164      6151       397   2020-06-24
# 14                  9721      150      6004       322   2020-06-23
# 15                  9399      142      5730       249   2020-06-22
# 16                  9150      137      5618       453   2020-06-21
# 17                  8697      132      5391       416   2020-06-20
# 18                  8281      124      5210       337   2020-06-19
# 19                  7944      114      4983       210   2020-06-18

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
# %matplotlib inline

# %%
plt.figure(figsize=(12,6))
ax = sns.barplot(x = df["Date Created"][::-1],y=df2['Total Confirmed Cases'],palette="Blues")
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()
ax.figure.savefig("./images/Karnataka-TCC.png")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-618309741b09> in <module>
#       1 plt.figure(figsize=(12,6))
# ----> 2 ax = sns.barplot(x = df["Date Created"][::-1],y=df2['Total Confirmed Cases'],palette="Blues")
#       3 ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
#       4 plt.tight_layout()
#       5 plt.show()
#
# ~\Ana\Anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3148                           estimator, ci, n_boot, units, seed,
#    3149                           orient, color, palette, saturation,
# -> 3150                           errcolor, errwidth, capsize, dodge)
#    3151
#    3152     if ax is None:
#
# ~\Ana\Anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1613         """Initialize the plotter."""
#    1614         self.establish_variables(x, y, hue, data, orient,
# -> 1615                                  order, hue_order, units)
#    1616         self.establish_colors(color, palette, saturation)
#    1617         self.estimate_statistic(estimator, ci, n_boot, seed)
#
# ~\Ana\Anaconda3\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     153
#     154             # Figure out the plotting orientation
# --> 155             orient = self.infer_orient(x, y, orient)
#     156
#     157             # Option 2a:
#
# ~\Ana\Anaconda3\lib\site-packages\seaborn\categorical.py in infer_orient(self, x, y, orient)
#     359                 return "h"
#     360         elif is_not_numeric(y):
# --> 361             if is_not_numeric(x):
#     362                 raise ValueError(no_numeric)
#     363             else:
#
# ~\Ana\Anaconda3\lib\site-packages\seaborn\categorical.py in is_not_numeric(s)
#     338         def is_not_numeric(s):
#     339             try:
# --> 340                 np.asarray(s, dtype=np.float)
#     341             except ValueError:
#     342                 return True
#
# ~\AppData\Roaming\Python\Python37\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ~\Ana\Anaconda3\lib\site-packages\pandas\core\series.py in __array__(self, dtype)
#     752               dtype='datetime64[ns]')
#     753         """
# --> 754         return np.asarray(self.array, dtype)
#     755
#     756     # ----------------------------------------------------------------------
#
# ~\AppData\Roaming\Python\Python37\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ~\Ana\Anaconda3\lib\site-packages\pandas\core\arrays\numpy_.py in __array__(self, dtype)
#     182
#     183     def __array__(self, dtype=None) -> np.ndarray:
# --> 184         return np.asarray(self._ndarray, dtype=dtype)
#     185
#     186     _HANDLED_TYPES = (np.ndarray, numbers.Number)
#
# ~\AppData\Roaming\Python\Python37\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# TypeError: float() argument must be a string or a number, not 'datetime.date'

# %%
plt.figure(figsize=(12,6))
ax = sns.barplot(x = df["Date Created"][::-1],y=df2['Deceased'],palette="Blues")
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()
ax.figure.savefig("./images/Karnataka-DC.png")

# %%
plt.figure(figsize=(12,6))
ax = sns.barplot(x = df["Date Created"][::-1],y=df2['Recovered'],palette="Blues")
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()
ax.figure.savefig("./images/Karnataka-RC.png")

# %%
plt.figure(figsize=(12,6))
ax = sns.barplot(x = df["Date Created"][::-1],y=df2['New Cases'],palette="Blues")
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()
ax.figure.savefig("./images/Karnataka-NC.png")
