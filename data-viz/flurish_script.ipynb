# %% [markdown]
# https://public.flourish.studio/visualisation/2906911/
# # For website -

# %% [markdown]
# div class="flourish-embed flourish-bar-chart-race" data-src="visualisation/2906911" data-url="https://flo.uri.sh/visualisation/2906911/embed"><script src="https://public.flourish.studio/resources/embed.js"></script></div

# %%
import pandas as pd

# %%
df = pd.read_csv('covid_19_clean_complete.csv')
df = df.groupby(['Date', 'Country/Region'])['Confirmed'].sum().reset_index()
df['Date'] = pd.to_datetime(df['Date'])
df = df.sort_values('Date')
df = df.pivot(index='Country/Region', columns='Date', values='Confirmed').reset_index()
df.head()
# Out:
# Date Country/Region  2020-01-22 00:00:00  2020-01-23 00:00:00  \
# 0       Afghanistan                    0                    0
# 1           Albania                    0                    0
# 2           Algeria                    0                    0
# 3           Andorra                    0                    0
# 4            Angola                    0                    0
#
# Date  2020-01-24 00:00:00  2020-01-25 00:00:00  2020-01-26 00:00:00  \
# 0                       0                    0                    0
# 1                       0                    0                    0
# 2                       0                    0                    0
# 3                       0                    0                    0
# 4                       0                    0                    0
#
# Date  2020-01-27 00:00:00  2020-01-28 00:00:00  2020-01-29 00:00:00  \
# 0                       0                    0                    0
# 1                       0                    0                    0
# 2                       0                    0                    0
# 3                       0                    0                    0
# 4                       0                    0                    0
#
# Date  2020-01-30 00:00:00  ...  2020-06-09 00:00:00  2020-06-10 00:00:00  \
# 0                       0  ...                21459                22142
# 1                       0  ...                 1299                 1341
# 2                       0  ...                10382                10484
# 3                       0  ...                  852                  852
# 4                       0  ...                   96                  113
#
# Date  2020-06-11 00:00:00  2020-06-12 00:00:00  2020-06-13 00:00:00  \
# 0                   22890                23546                24102
# 1                    1385                 1416                 1464
# 2                   10589                10698                10810
# 3                     852                  853                  853
# 4                     118                  130                  138
#
# Date  2020-06-14 00:00:00  2020-06-15 00:00:00  2020-06-16 00:00:00  \
# 0                   24766                25527                26310
# 1                    1521                 1590                 1672
# 2                   10919                11031                11147
# 3                     853                  853                  854
# 4                     140                  142                  148
#
# Date  2020-06-17 00:00:00  2020-06-18 00:00:00
# 0                   26874                27532
# 1                    1722                 1788
# 2                   11268                11385
# 3                     854                  855
# 4                     155                  166
#
# [5 rows x 150 columns]

# %%
df.to_csv('flurish_data.csv')
