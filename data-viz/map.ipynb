# %%
from datetime import datetime
import os
import re
import glob
import requests 
import pandas as pd
from bs4 import BeautifulSoup
import re
import numpy as np
import folium

# %%
df=pd.read_csv('worldometer_data.csv')
df=df.set_index(df['Country/Region'])
df.head()
# Out:
#                Country/Region Continent  Population  TotalCases TotalDeaths  \
# Country/Region
# Afghanistan       Afghanistan      Asia    38901392       29481         618
# Albania               Albania    Europe     2877855        1995          44
# Algeria               Algeria    Africa    43828594       11920         852
# Andorra               Andorra    Europe       77263         855          52
# Angola                 Angola    Africa    32830010         186          10
#
#                TotalRecovered ActiveCases  Tot Cases/1M pop Deaths/1M pop  \
# Country/Region
# Afghanistan              9260       19603               758            16
# Albania                  1159         792               693            15
# Algeria                  8559        2509               272            19
# Andorra                   796           7             11066           673
# Angola                     77          99                 6           0.3
#
#                    TotalTests   Tests/1M pop            WHO Region
# Country/Region
# Afghanistan             66800           1717  EasternMediterranean
# Albania                 20762           7214                Europe
# Algeria         Not Available  Not Available                Africa
# Andorra                  3750          48536                Europe
# Angola                  10000            305                Africa

# %%
countries = pd.read_html("https://developers.google.com/public-data/docs/canonical/countries_csv")[0]
countries=countries.set_index(countries['name'])
countries.head()
# Out:
#                      country   latitude  longitude                  name
# name
# Andorra                   AD  42.546245   1.601554               Andorra
# United Arab Emirates      AE  23.424076  53.847818  United Arab Emirates
# Afghanistan               AF  33.939110  67.709953           Afghanistan
# Antigua and Barbuda       AG  17.060816 -61.796428   Antigua and Barbuda
# Anguilla                  AI  18.220554 -63.068615              Anguilla

# %%
lat,long=[],[]
m_lat,m_long=[],[]
for country in df['Country/Region']:
    try:
        lat.append((country,countries.loc[country.strip()]['latitude']))
    except:
        m_lat.append(country)
for country in df['Country/Region']:
    try:
        long.append((country,countries.loc[country.strip()]['longitude']))
    except:
        m_long.append(country)

m_lat
# Out:
# ['CAR',
#  'Cabo Verde',
#  'Channel Islands',
#  'Congo',
#  'Curaçao',
#  'Czechia',
#  'DRC',
#  'Eswatini',
#  'Faeroe Islands',
#  'Falkland Islands',
#  'Ivory Coast',
#  'Macao',
#  'Myanmar',
#  'North Macedonia',
#  'Palestine',
#  'S. Korea',
#  'Saint Martin',
#  'Sao Tome and Principe',
#  'Sint Maarten',
#  'South Sudan',
#  'St. Vincent Grenadines',
#  'Turks and Caicos',
#  'UAE',
#  'UK',
#  'USA']

# %%
s=''
for i in m_lat:
    s+='("{}",),'.format(i)
print(s)
# Out:
# ("CAR",),("Cabo Verde",),("Channel Islands",),("Congo",),("Curaçao",),("Czechia",),("DRC",),("Eswatini",),("Faeroe Islands",),("Falkland Islands",),("Ivory Coast",),("Macao",),("Myanmar",),("North Macedonia",),("Palestine",),("S. Korea",),("Saint Martin",),("Sao Tome and Principe",),("Sint Maarten",),("South Sudan",),("St. Vincent Grenadines",),("Turks and Caicos",),("UAE",),("UK",),("USA",),

# %%
lat+=[("CAR",6.111),("Cabo Verde",6.5388),("Channel Islands",49.372284),("Congo",4.0383),("Curaçao",12.1696),("Czechia",49.8175),("DRC",4.0383),("Eswatini",26.5225),("Faeroe Islands",61.8926),("Falkland Islands",51.7963),("Ivory Coast",7.5400),("Macao",22.1987),("Myanmar",21.9162),("North Macedonia",41.6086),("Palestine",31.9522),("S. Korea",35.9078),("Saint Martin",18.0708),("Sao Tome and Principe",0.1864),("Sint Maarten",18.0425),("South Sudan",6.8770),("St. Vincent Grenadines",12.9843),("Turks and Caicos",21.6940),("UAE",23.4241),("UK",55.3781),("USA",37.0902)]

long+=[("CAR",23.9394),("Cabo Verde",23.0418),("Channel Islands",-2.364351),("Congo",21.7587),("Curaçao",68.99),("Czechia",15.473),("DRC",25.7587),("Eswatini",31.4659),("Faeroe Islands",6.9118),("Falkland Islands",59.5236),("Ivory Coast",5.5471),("Macao",113.5439),("Myanmar",95.956),("North Macedonia",21.7453),("Palestine",35.2332),("S. Korea",127.7669),("Saint Martin",63.0501),("Sao Tome and Principe",6.6131),("Sint Maarten",63.0548),("South Sudan",31.307),("St. Vincent Grenadines",61.2872),("Turks and Caicos",71.7979),("UAE",53.8478),("UK",3.436),("USA",95.7129)]

# %%
del df["Country/Region"]
lat.sort()
long.sort()
df.sort_values("Country/Region",inplace=True)
df.head()
# Out:
#                Continent  Population  TotalCases TotalDeaths TotalRecovered  \
# Country/Region
# Afghanistan         Asia    38901392       29481         618           9260
# Albania           Europe     2877855        1995          44           1159
# Algeria           Africa    43828594       11920         852           8559
# Andorra           Europe       77263         855          52            796
# Angola            Africa    32830010         186          10             77
#
#                ActiveCases  Tot Cases/1M pop Deaths/1M pop     TotalTests  \
# Country/Region
# Afghanistan          19603               758            16          66800
# Albania                792               693            15          20762
# Algeria               2509               272            19  Not Available
# Andorra                  7             11066           673           3750
# Angola                  99                 6           0.3          10000
#
#                  Tests/1M pop            WHO Region
# Country/Region
# Afghanistan              1717  EasternMediterranean
# Albania                  7214                Europe
# Algeria         Not Available                Africa
# Andorra                 48536                Europe
# Angola                    305                Africa

# %%
count=0
for i,j in zip([x[0] for x in lat],df.index):
    if i!=j:
        count+=1
print(count)

count1=0
for i,j in zip([x[0] for x in long],df.index):
    if i!=j:
        count1+=1
print(count1)
# Out:
# 0
# 0

# %%
df['Latitude']=[x[1] for x in lat]
df['Longitude']=[y[1] for y in long]
df.tail()
# Out:
#                Continent  Population  TotalCases    TotalDeaths  \
# Country/Region
# Vietnam             Asia    97317898         349  Not Available
# Western Sahara    Africa      596871          10              1
# Yemen               Asia    29805944         967            257
# Zambia            Africa    18366582        1430             11
# Zimbabwe          Africa    14857190         512              6
#
#                TotalRecovered ActiveCases  Tot Cases/1M pop  Deaths/1M pop  \
# Country/Region
# Vietnam                   328          21                 4  Not Available
# Western Sahara              8           1                17              2
# Yemen                     350         360                32              9
# Zambia                   1194         225                78            0.6
# Zimbabwe                   64         442                34            0.4
#
#                    TotalTests   Tests/1M pop            WHO Region   Latitude  \
# Country/Region
# Vietnam                275000           2826        WesternPacific  14.058324
# Western Sahara  Not Available  Not Available                Africa  24.215527
# Yemen                     120              4  EasternMediterranean  15.552727
# Zambia                  47968           2612                Africa -13.133897
# Zimbabwe                52905           3561                Africa -19.015438
#
#                  Longitude
# Country/Region
# Vietnam         108.277199
# Western Sahara  -12.885834
# Yemen            48.516388
# Zambia           27.849332
# Zimbabwe         29.154857

# %%
df=df.reset_index()
df.head()
# Out:
#   Country/Region Continent  Population  TotalCases TotalDeaths TotalRecovered  \
# 0    Afghanistan      Asia    38901392       29481         618           9260
# 1        Albania    Europe     2877855        1995          44           1159
# 2        Algeria    Africa    43828594       11920         852           8559
# 3        Andorra    Europe       77263         855          52            796
# 4         Angola    Africa    32830010         186          10             77
#
#   ActiveCases  Tot Cases/1M pop Deaths/1M pop     TotalTests   Tests/1M pop  \
# 0       19603               758            16          66800           1717
# 1         792               693            15          20762           7214
# 2        2509               272            19  Not Available  Not Available
# 3           7             11066           673           3750          48536
# 4          99                 6           0.3          10000            305
#
#              WHO Region   Latitude  Longitude
# 0  EasternMediterranean  33.939110  67.709953
# 1                Europe  41.153332  20.168331
# 2                Africa  28.033886   1.659626
# 3                Europe  42.546245   1.601554
# 4                Africa -11.202692  17.873887

# %%
# f = folium.Figure(width=1000, height=500)
map = folium.Map(location=[50,50], max_bounds = True, zoom_start=1.5,min_zoom = 1,width='100%',height='100%')
for index in range(len(df)):
    summary="""
    <strong><i>Total Cases:</i></striong>{}<br>
    <i><font color = red>Total Deaths: </font></i>{}<br>
    <i><font color = green>Total Recovered:</font></i>{}<br>
    <i>Active Cases:</i>{}<br>
    <i>Total Tests:</i>{}<br>
            """.format(df.iloc[index]['TotalCases'],df.iloc[index]['TotalDeaths'],df.iloc[index]['TotalRecovered'],df.iloc[index]['ActiveCases'],df.iloc[index]['TotalTests'])
    country=df.iloc[index]['Country/Region']
    latitude=df.iloc[index]['Latitude']
    longitude=df.iloc[index]['Longitude']
    folium.Marker([latitude,longitude], popup='<font color = blue><b>'+country+'<br></b></font>'+summary, tooltip=country).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
